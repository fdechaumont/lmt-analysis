# %% [markdown]
# # Using the lmt-analysis library with Jupyter
#
# We show here some basic examples of Live Mouse Tracker analysis.
#
# Video demo and available databases: https://livemousetracker.org/
# Paper : https://www.biorxiv.org/content/10.1101/345132v2
# mail: chaumont@pasteur.fr, elodie.ey@pasteur.fr
# Twitter : @fabdechaumont
# Another tutorial of the this lib (slide presentation): https://docs.google.com/presentation/d/1wR7JM2vq5ZjugrwDe4YuuKJm0MWIvkHAvrOH7mQNOEk/edit?usp=sharing
#
# How to use run this tutorial with your data:
# 1. Download or connect a git client to the lmt-analysis repository : https://github.com/fdechaumont/lmt-analysis
# 2. Download the demo database produced by Live Mouse Tracker: http://bioimageanalysis.org
# 3. Install anaconda, and run the jupyter notebook: https://www.anaconda.com/distribution/
# 4. Point your browser to this file (example/Examples with Jupyter)
# /lmt/20180110_validation_4_ind_Experiment_6644.zip
# 5. Run
# 6. Select the database you just downloaded when asked.
# 7. Enjoy the results.

# %% [markdown]
# ## Performs the imports:
# * The only diffence with the original python code is the import that needs the following lines to work:
# ```python
# import sys
# sys.path.insert(1, "../")
# ```

# %%
'''
Created on 15 fev. 2019

@author: Fab
'''
# %matplotlib inline

import sys
sys.path.insert(1, "../")


import pandas as pd
import numpy as np

import sqlite3
from lmtanalysis.FileUtil import getFilesToProcess

from lmtanalysis.Animal import AnimalPool
from lmtanalysis.Measure import *
from lmtanalysis.Event import EventTimeLine, plotMultipleTimeLine

# %% [markdown]
# ## Ask file to process to the user with a dialog window:
# * note: You can run this step only once, and then keep processing the file(s) with the next cells.
# * note2: the file window can be hidden by other windows.

# %%
#ask the user for database to process
print( "Select file name in window")
files = getFilesToProcess()
# Out:
# Select file name in window

# %% [markdown]
# ## Display trajectories of animals
# * For this example we filter data from 0 to 1 hour
# * Trajectories are plotted considering the kinect resolution.
#     * 30 detections per second
#     * 512x424 infra red sensor resolution

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )
    

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    # plot and show trajectory
    animalPool.plotTrajectory()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E956F564D0>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.22573518753051758 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E956F564D0>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.11658644676208496 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E956F564D0>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.23807573318481445 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E956F564D0>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.11674261093139648 seconds.
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Filter trajectories : keep tracks which are slower than 2cm/s

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    # filter detection by animalSpeed (speed is in centimeters per second)
    animalPool.filterDetectionByInstantSpeed( 0, 2 )

    # plot and show trajectory
    animalPool.plotTrajectory( title="Trajectories filtered by speed (max 2) ")
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480400>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.215728759765625 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480400>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.11559939384460449 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480400>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.10721445083618164 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480400>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.23934412002563477 seconds.
# Filtering Instant speed min: 0 max: 2 number of detection removed: 20444
# Filtering Instant speed min: 0 max: 2 number of detection removed: 19052
# Filtering Instant speed min: 0 max: 2 number of detection removed: 19345
# Filtering Instant speed min: 0 max: 2 number of detection removed: 18037
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Get time spent in area
# * In this example we only keep the area where the house has been placed
# * Numbers on the graph is the RFID number of the animal

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the 3 minutes
    animalPool.loadDetection( start = 0, end = 3*oneMinute )

    # filter detection by area (in cm from the top left of the cage)
    animalPool.filterDetectionByArea( 0, 30, 25, 50 )

    # loop over all animals in this database
    for animal in animalPool.getAnimalList():

        # print RFID of animal
        print ( "Animal : " , animal.RFID )
        # number of frame in which the animal has been detected:
        numberOfFrame = len ( animal.detectionDictionary.keys() )
        # we have 30 frames per second
        timeInSecond = numberOfFrame / 30
        # print result
        print( "Time spent in area: (in second): " , timeInSecond )

    animalPool.plotTrajectory( title="Trajectories filtered by area" , scatter=True )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5400
# <sqlite3.Connection object at 0x000001E957482980>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   5388  detections loaded in 0.028725624084472656 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5400
# <sqlite3.Connection object at 0x000001E957482980>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   5398  detections loaded in 0.02451014518737793 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5400
# <sqlite3.Connection object at 0x000001E957482980>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   5380  detections loaded in 0.0244903564453125 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5400
# <sqlite3.Connection object at 0x000001E957482980>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   5391  detections loaded in 0.024426698684692383 seconds.
# Filtering area, number of detection removed: 2859
# Filtering area, number of detection removed: 3742
# Filtering area, number of detection removed: 3507
# Filtering area, number of detection removed: 4585
# Animal :  000004395862
# Time spent in area: (in second):  84.3
# Animal :  000004395854
# Time spent in area: (in second):  55.2
# Animal :  000004396001
# Time spent in area: (in second):  62.43333333333333
# Animal :  000004395671
# Time spent in area: (in second):  26.866666666666667
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## 3D rendering of the trajectory

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first 3 minutes
    animalPool.loadDetection( start = 0, end = 3*oneMinute )

    # filter detection by area (in cm from the top left of the cage)
    animalPool.filterDetectionByArea( 0, 30, 25, 50 )

    # loop over all animals in this database
    for animal in animalPool.getAnimalList():

        animal.plotTrajectory3D()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004612582 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004612467 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004612582 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:1 Name:A RFID:000004612582 Genotype:None User1:None   16924  detections loaded in 0.21877026557922363 seconds.
# Animal Id:2 Name:B RFID:000004612467 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:2 Name:B RFID:000004612467 Genotype:None User1:None   16927  detections loaded in 0.2812364101409912 seconds.
# Filtering area, number of detection removed: 14913
# Filtering area, number of detection removed: 13653
# Draw 3D trajectory
# Draw 3D trajectory

# %% [markdown]
# ## Displays distance traveled in cm and use scatter plot style

# %%
for file in files:
    
    # connect to database
    connection = sqlite3.connect( file )
    
    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()
    
    # load infos about the animals
    animalPool.loadAnimals( connection )
    
    # load all detection (positions) of all animals for the first 10 minutes
    animalPool.loadDetection( start = 0, end = 10*oneMinute )
    
    # filter detection by area (in cm from the top left of the cage)
    animalPool.filterDetectionByArea( 0, 30, 25, 50 )
    
    # loop over all animals in this database
    for animal in animalPool.getAnimalList():
        
        # print RFID of animal
        print ( "Animal : " , animal.RFID )
        # distance traveled by animal (in cm):            
        print( "Distance traveled in area: (in centimeter): " , animal.getDistance( ) )
        
    animalPool.plotTrajectory( title="Trajectories filtered by area" , scatter=True )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# <sqlite3.Connection object at 0x000001E94F13BE20>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   17983  detections loaded in 0.10582876205444336 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# <sqlite3.Connection object at 0x000001E94F13BE20>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   17981  detections loaded in 0.08861613273620605 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# <sqlite3.Connection object at 0x000001E94F13BE20>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   17781  detections loaded in 0.20582151412963867 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# <sqlite3.Connection object at 0x000001E94F13BE20>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   17982  detections loaded in 0.09231090545654297 seconds.
# Filtering area, number of detection removed: 11338
# Filtering area, number of detection removed: 10970
# Filtering area, number of detection removed: 10668
# Filtering area, number of detection removed: 11911
# Animal :  000004395862
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2108.248055883141
# Animal :  000004395854
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2083.4652344996243
# Animal :  000004396001
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2200.714233808731
# Animal :  000004395671
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  1560.7031632324788
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Show event timeline
# * In this example, we show the time line for the event "Oral-genital contact" for the first our of experiment
# * Note that time line can be very dense and may not be displayed correctly. Consider saving them as PDF and then open it in a reader to get the proper display.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", minFrame = 0, maxFrame = oneHour )
    
    eventTimeLine.plotTimeLine()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482B60>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.20985794067382812 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482B60>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.11366796493530273 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482B60>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.2313523292541504 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482B60>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.11870861053466797 seconds.
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( None , None , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 423  records loaded in  0.03860926628112793 S )

# %% [markdown]
# ## Show multiple timeline with id

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine1 = EventTimeLine( connection, "Oral-genital Contact", idA = 1, idB = 2, minFrame = 0, maxFrame = oneHour )        
    eventTimeLine2 = EventTimeLine( connection, "Oral-genital Contact", idA = 2, idB = 1, minFrame = 0, maxFrame = oneHour )

    plotMultipleTimeLine( [ eventTimeLine1, eventTimeLine2 ] )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480F40>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.12102937698364258 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480F40>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.207535982131958 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480F40>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.1331472396850586 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957480F40>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.12277650833129883 seconds.
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=1 AND IDANIMALB=2 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 49  records loaded in  0.04258847236633301 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=2 AND IDANIMALB=1 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 46  records loaded in  0.04075980186462402 S )

# %% [markdown]
# ## Show timeline with all different id combinaison
# * In this experiment we have 4 animals
# * This script will show all animal combinations for this time line.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLineList = []
    for a in animalPool.getAnimalDictionary():
        for b in animalPool.getAnimalDictionary():
            if a == b:
                continue
            eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", idA = a, idB = b, minFrame = 0, maxFrame = oneHour )
            eventTimeLineList.append( eventTimeLine )        

    plotMultipleTimeLine( eventTimeLineList )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482110>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.20011663436889648 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482110>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.11765837669372559 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482110>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.10631203651428223 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482110>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.22720789909362793 seconds.
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=1 AND IDANIMALB=2 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 49  records loaded in  0.0401148796081543 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=1 AND IDANIMALB=3 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 49  records loaded in  0.03627943992614746 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=1 AND IDANIMALB=4 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 42  records loaded in  0.03624534606933594 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=2 AND IDANIMALB=1 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 46  records loaded in  0.03773832321166992 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=2 AND IDANIMALB=3 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 48  records loaded in  0.03743886947631836 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=2 AND IDANIMALB=4 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 35  records loaded in  0.038278818130493164 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=3 AND IDANIMALB=1 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 64  records loaded in  0.03796648979187012 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=3 AND IDANIMALB=2 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 55  records loaded in  0.03578042984008789 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=3 AND IDANIMALB=4 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 35  records loaded in  0.03539872169494629 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=4 AND IDANIMALB=1 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 37  records loaded in  0.03547501564025879 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=4 AND IDANIMALB=2 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 18  records loaded in  0.03534221649169922 S )
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=4 AND IDANIMALB=3 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 31  records loaded in  0.036454200744628906 S )

# %% [markdown]
# ## Number and duration of events
#
# In this example we extract the duration of the events, and we display them with pandas.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", idA = 1 , idB = 2, minFrame = 0, maxFrame = oneHour )

    print ( "Event list for label ", eventTimeLine.eventNameWithId )
    print ( "for animal 1:", animalPool.getAnimalDictionary()[1].RFID )
    print ( "for animal 2:", animalPool.getAnimalDictionary()[2].RFID )
    print ( "Number of events:", len( eventTimeLine.getEventList() ) )

    import pandas as pd
    
    #df = pd.DataFrame( columns=( "Start frame","End frame", "Duration (in frame)" )
    #print ( "start frame","end frame", "duration(in frame)")        
    
    data = []
    
    for event in eventTimeLine.eventList:
        data.append( [ event.startFrame, event.endFrame, event.duration() ] )
        #print( event.startFrame, event.endFrame, event.duration() )

import pandas as pd
import numpy as np

df = pd.DataFrame( data = np.array( data ), columns=[ "Start frame","End frame", "Duration (in frame)" ] )

df
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E9574809A0>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.12178421020507812 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E9574809A0>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.21991658210754395 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E9574809A0>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.1203298568725586 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E9574809A0>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.1115560531616211 seconds.
# SELECT * FROM EVENT WHERE NAME='Oral-genital Contact' AND IDANIMALA=1 AND IDANIMALB=2 AND ENDFRAME>=0 AND STARTFRAME<=108000 ORDER BY STARTFRAME
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 108000 ) Loaded ( 49  records loaded in  0.041500091552734375 S )
# Event list for label  Oral-genital Contact idA:1 idB:2 idC:None idD:None
# for animal 1: 000004395862
# for animal 2: 000004395854
# Number of events: 49
#     Start frame  End frame  Duration (in frame)
# 0           217        221                    5
# 1           552        559                    8
# 2           693        694                    2
# 3          3265       3267                    3
# 4          3710       3718                    9
# 5          4494       4494                    1
# 6          4496       4501                    6
# 7          4542       4542                    1
# 8          4545       4545                    1
# 9          4553       4553                    1
# 10         6279       6280                    2
# 11         8465       8478                   14
# 12         9527       9527                    1
# 13         9918       9919                    2
# 14        10511      10514                    4
# 15        10516      10519                    4
# 16        11524      11528                    5
# 17        11561      11582                   22
# 18        11821      11822                    2
# 19        11829      11833                    5
# 20        11841      11844                    4
# 21        12258      12258                    1
# 22        12260      12263                    4
# 23        12267      12267                    1
# 24        12270      12274                    5
# 25        12276      12276                    1
# 26        12278      12278                    1
# 27        12281      12284                    4
# 28        12295      12314                   20
# 29        12399      12399                    1
# 30        14190      14197                    8
# 31        14203      14205                    3
# 32        14359      14365                    7
# 33        14370      14370                    1
# 34        14708      14708                    1
# 35        14710      14712                    3
# 36        14714      14720                    7
# 37        14722      14726                    5
# 38        14764      14764                    1
# 39        14769      14771                    3
# 40        15799      15800                    2
# 41        16945      16945                    1
# 42        20022      20023                    2
# 43        20027      20029                    3
# 44        20072      20072                    1
# 45        20074      20074                    1
# 46        21553      21553                    1
# 47        23239      23248                   10
# 48        23259      23264                    6

# %% [markdown]
# ## Show the mask of the animal at t=300
#
# This code grabs the data from the *data* field of the detection table. It unzip the mask used as region of interest to display it in a figure, so that you can see the silhouette of the animals

# %%
for file in files:

    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    
    # show the mask of animals at frame 300
    animalPool.showMask( 300 )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None

# %% [markdown]
# # Show (x,y,z) position of the first animal
# For the purpose of the example and for the limit the output size, we take the first file, and we process the first animal

# %%
file = files[0]
    
# connect to database
connection = sqlite3.connect( file )

# create an animalPool, which basically contains your animals
animalPool = AnimalPool()

animalPool.loadAnimals( connection )

# load all detection (positions) of all animals for the first hour
animalPool.loadDetection( start = 0, end = oneHour )

animal = animalPool.animalDictionary[1]

print ("******")
print ( animal )

print ("Position coordinates:")

data = []

for detectionKey in animal.detectionDictionary:
    detection = animal.detectionDictionary[ detectionKey ]
    t = detectionKey
    x = detection.massX
    y = detection.massY
    z = detection.massZ
    data.append( [ t,x,y,z ] )

df = pd.DataFrame( data = np.array( data ), columns=[ "frame number", "x","y","z" ] )

df
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal type = MOUSE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal type = MOUSE
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482020>
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None   23873  detections loaded in 0.20043730735778809 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482020>
# Animal Id:2 Name:B RFID:000004395854 Genotype:None Strain:None Age:None Sex:None Setup:None   23863  detections loaded in 0.11249446868896484 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482020>
# Animal Id:3 Name:C RFID:000004396001 Genotype:None Strain:None Age:None Sex:None Setup:None   23671  detections loaded in 0.11194968223571777 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# <sqlite3.Connection object at 0x000001E957482020>
# Animal Id:4 Name:D RFID:000004395671 Genotype:None Strain:None Age:None Sex:None Setup:None   23864  detections loaded in 0.223419189453125 seconds.
# ******
# Animal Id:1 Name:A RFID:000004395862 Genotype:None Strain:None Age:None Sex:None Setup:None
# Position coordinates:
#        frame number       x       y      z
# 0               2.0  274.31  333.42  57.16
# 1               3.0  276.53  333.90  56.16
# 2               4.0  279.30  333.53  55.84
# 3               5.0  282.30  333.28  56.40
# 4               6.0  285.72  333.53  56.36
# ...             ...     ...     ...    ...
# 23868       23886.0  379.23  204.64  58.52
# 23869       23887.0  379.01  199.32  57.88
# 23870       23888.0  379.59  192.90  54.28
# 23871       23889.0  378.98  187.59  51.08
# 23872       23890.0  379.36  182.93  51.96
#
# [23873 rows x 4 columns]
