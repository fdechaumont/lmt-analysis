# %% [markdown]
# # Using the lmt-analysis library with Jupyter
#
# We show here some basic examples of Live Mouse Tracker analysis.
#
# Video demo and available databases: https://livemousetracker.org/
# Paper : https://www.biorxiv.org/content/10.1101/345132v2
# mail: chaumont@pasteur.fr, elodie.ey@pasteur.fr
# Twitter : @fabdechaumont
# Another tutorial of the this lib (slide presentation): https://docs.google.com/presentation/d/1wR7JM2vq5ZjugrwDe4YuuKJm0MWIvkHAvrOH7mQNOEk/edit?usp=sharing
#
# How to use run this tutorial with your data:
# 1. Download or connect a git client to the lmt-analysis repository : https://github.com/fdechaumont/lmt-analysis
# 2. Download the demo database produced by Live Mouse Tracker: http://bioimageanalysis.org
# 3. Install anaconda, and run the jupyter notebook: https://www.anaconda.com/distribution/
# 4. Point your browser to this file (example/Examples with Jupyter)
# /lmt/20180110_validation_4_ind_Experiment_6644.zip
# 5. Run
# 6. Select the database you just downloaded when asked.
# 7. Enjoy the results.

# %% [markdown]
# ## Performs the imports:
# * The only diffence with the original python code is the import that needs the following lines to work:
# ```python
# import sys
# sys.path.insert(1, "../")
# ```

# %%
# %%capture
'''
Created on 15 fev. 2019

@author: Fab
'''

# %matplotlib inline

import sys
sys.path.insert(1, "../")


import pandas as pd
import numpy as np

import sqlite3
from lmtanalysis.FileUtil import getFilesToProcess

from lmtanalysis.Animal import AnimalPool
from lmtanalysis.Measure import *
from lmtanalysis.Event import EventTimeLine, plotMultipleTimeLine

# %% [markdown]
# ## Ask file to process to the user with a dialog window:
# * note: You can run this step only once, and then keep processing the file(s) with the next cells.
# * note2: the file window can be hidden by other windows.

# %%
#ask the user for database to process
print( "Select file name in window")
files = getFilesToProcess()
# Out:
# Select file name in window

# %% [markdown]
# ## Display trajectories of animals
# * For this example we filter data from 0 to 1 hour
# * Trajectories are plotted considering the kinect resolution.
#     * 30 detections per second
#     * 512x424 infra red sensor resolution

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )
    

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    # plot and show trajectory
    animalPool.plotTrajectory()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 4.980934143066406 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.5162529945373535 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.46089720726013184 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.4721395969390869 seconds.
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Filter trajectories : keep tracks which are slower than 2cm/s

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    # filter detection by animalSpeed (speed is in centimeters per second)
    animalPool.filterDetectionByInstantSpeed( 0, 2 )

    # plot and show trajectory
    animalPool.plotTrajectory( title="Trajectories filtered by speed (max 2) ")
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.3749659061431885 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.5483086109161377 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.47742199897766113 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.4905223846435547 seconds.
# Filtering Instant speed min: 0 max: 2 number of detection removed: 20444
# Filtering Instant speed min: 0 max: 2 number of detection removed: 19052
# Filtering Instant speed min: 0 max: 2 number of detection removed: 19345
# Filtering Instant speed min: 0 max: 2 number of detection removed: 18037
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Get time spent in area
# * In this example we only keep the area where the house has been placed
# * Numbers on the graph is the RFID number of the animal

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = 10*oneMinute )

    # filter detection by area (in cm from the top left of the cage)
    animalPool.filterDetectionByArea( 0, 30, 25, 50 );

    # loop over all animals in this database
    for animal in animalPool.getAnimalList():

        # print RFID of animal
        print ( "Animal : " , animal.RFID )
        # number of frame in which the animal has been detected:
        numberOfFrame = len ( animal.detectionDictionnary.keys() )
        # we have 30 frames per second
        timeInSecond = numberOfFrame / 30
        # print result
        print( "Time spent in area: (in second): " , timeInSecond )

    animalPool.plotTrajectory( title="Trajectories filtered by area" , scatter=True )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   17983  detections loaded in 0.33643293380737305 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   17981  detections loaded in 0.4382362365722656 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   17781  detections loaded in 0.3897671699523926 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   17982  detections loaded in 0.4024467468261719 seconds.
# Filtering area, number of detection removed: 11338
# Filtering area, number of detection removed: 10970
# Filtering area, number of detection removed: 10668
# Filtering area, number of detection removed: 11911
# Animal :  000004395862
# Time spent in area: (in second):  221.5
# Animal :  000004395854
# Time spent in area: (in second):  233.7
# Animal :  000004396001
# Time spent in area: (in second):  237.1
# Animal :  000004395671
# Time spent in area: (in second):  202.36666666666667
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## 3D rendering of the trajectory

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = 10*oneMinute )

    # filter detection by area (in cm from the top left of the cage)
    animalPool.filterDetectionByArea( 0, 30, 25, 50 );

    # loop over all animals in this database
    for animal in animalPool.getAnimalList():

        animal.plotTrajectory3D()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   17983  detections loaded in 0.4239683151245117 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   17981  detections loaded in 0.36566781997680664 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   17781  detections loaded in 0.3998439311981201 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   17982  detections loaded in 0.41256070137023926 seconds.
# Filtering area, number of detection removed: 11338
# Filtering area, number of detection removed: 10970
# Filtering area, number of detection removed: 10668
# Filtering area, number of detection removed: 11911
# Draw 3D trajectory
# Draw 3D trajectory
# Draw 3D trajectory
# Draw 3D trajectory

# %% [markdown]
# ## Displays distance traveled in cm and use scatter plot style

# %%
    for file in files:
        
        # connect to database
        connection = sqlite3.connect( file )
        
        # create an animalPool, which basically contains your animals
        animalPool = AnimalPool()
        
        # load infos about the animals
        animalPool.loadAnimals( connection )
        
        # load all detection (positions) of all animals for the first hour
        animalPool.loadDetection( start = 0, end = 10*oneMinute )
        
        # filter detection by area (in cm from the top left of the cage)
        animalPool.filterDetectionByArea( 0, 30, 25, 50 );
        
        # loop over all animals in this database
        for animal in animalPool.getAnimalList():
            
            # print RFID of animal
            print ( "Animal : " , animal.RFID )
            # distance traveled by animal (in cm):            
            print( "Distance traveled in area: (in centimeter): " , animal.getDistance( ) )
            
        animalPool.plotTrajectory( title="Trajectories filtered by area" , scatter=True )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   17983  detections loaded in 0.2969033718109131 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   17981  detections loaded in 0.3125014305114746 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   17781  detections loaded in 0.3749997615814209 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=18000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   17982  detections loaded in 0.3749969005584717 seconds.
# Filtering area, number of detection removed: 11338
# Filtering area, number of detection removed: 10970
# Filtering area, number of detection removed: 10668
# Filtering area, number of detection removed: 11911
# Animal :  000004395862
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2108.2480558831417
# Animal :  000004395854
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2083.4652344996243
# Animal :  000004396001
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  2200.714233808731
# Animal :  000004395671
# Compute total distance min:0 max:None
# Distance traveled in area: (in centimeter):  1560.7031632324788
# AnimalPool: plot trajectory.
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D
# Compute trajectory of animal A
# Draw trajectory of animal A
# Compute trajectory of animal B
# Draw trajectory of animal B
# Compute trajectory of animal C
# Draw trajectory of animal C
# Compute trajectory of animal D
# Draw trajectory of animal D

# %% [markdown]
# ## Show event timeline
# * In this example, we show the time line for the event "Oral-genital contact" for the first our of experiment
# * Note that time line can be very dense and may not be displayed correctly. Consider saving them as PDF and then open it in a reader to get the proper display.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", minFrame = 0, maxFrame = oneHour )
    
    eventTimeLine.plotTimeLine()
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.4860081672668457 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.41689229011535645 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.4627511501312256 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.4384281635284424 seconds.
# Oral-genital Contact  Id( None , None , None , None ) Loaded ( 423  records loaded in  0.48180580139160156 S )

# %% [markdown]
# ## Show multiple timeline with id

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine1 = EventTimeLine( connection, "Oral-genital Contact", idA = 1, idB = 2, minFrame = 0, maxFrame = oneHour )        
    eventTimeLine2 = EventTimeLine( connection, "Oral-genital Contact", idA = 2, idB = 1, minFrame = 0, maxFrame = oneHour )

    plotMultipleTimeLine( [ eventTimeLine1, eventTimeLine2 ] )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.4375288486480713 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.3905954360961914 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.5000207424163818 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.43752408027648926 seconds.
# Oral-genital Contact  Id( 1 , 2 , None , None ) Loaded ( 49  records loaded in  0.07808184623718262 S )
# Oral-genital Contact  Id( 2 , 1 , None , None ) Loaded ( 46  records loaded in  0.0625007152557373 S )
# C:\Users\Fab\Anaconda3bis\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# No handles with labels found to put in legend.

# %% [markdown]
# ## Show timeline with all different id combinaison
# * In this experiment we have 4 animals
# * This script will show all animal combinations for this time line.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLineList = []
    for a in animalPool.getAnimalDictionnary():
        for b in animalPool.getAnimalDictionnary():
            if a == b:
                continue
            eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", idA = a, idB = b, minFrame = 0, maxFrame = oneHour )
            eventTimeLineList.append( eventTimeLine )        

    plotMultipleTimeLine( eventTimeLineList )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.35938072204589844 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.515632152557373 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.43750739097595215 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.46871328353881836 seconds.
# Oral-genital Contact  Id( 1 , 2 , None , None ) Loaded ( 49  records loaded in  0.07814502716064453 S )
# Oral-genital Contact  Id( 1 , 3 , None , None ) Loaded ( 49  records loaded in  0.062499046325683594 S )
# Oral-genital Contact  Id( 1 , 4 , None , None ) Loaded ( 42  records loaded in  0.046875 S )
# Oral-genital Contact  Id( 2 , 1 , None , None ) Loaded ( 46  records loaded in  0.07812952995300293 S )
# Oral-genital Contact  Id( 2 , 3 , None , None ) Loaded ( 48  records loaded in  0.06249713897705078 S )
# Oral-genital Contact  Id( 2 , 4 , None , None ) Loaded ( 35  records loaded in  0.06247973442077637 S )
# Oral-genital Contact  Id( 3 , 1 , None , None ) Loaded ( 64  records loaded in  0.07812643051147461 S )
# Oral-genital Contact  Id( 3 , 2 , None , None ) Loaded ( 55  records loaded in  0.06254029273986816 S )
# Oral-genital Contact  Id( 3 , 4 , None , None ) Loaded ( 35  records loaded in  0.07811570167541504 S )
# Oral-genital Contact  Id( 4 , 1 , None , None ) Loaded ( 37  records loaded in  0.062474727630615234 S )
# Oral-genital Contact  Id( 4 , 2 , None , None ) Loaded ( 18  records loaded in  0.07814502716064453 S )
# Oral-genital Contact  Id( 4 , 3 , None
# C:\Users\Fab\Anaconda3bis\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# No handles with labels found to put in legend.
#  , None ) Loaded ( 31  records loaded in  0.06247711181640625 S )

# %% [markdown]
# ## Number and duration of events
#
# In this example we extract the duration of the events, and we display them with pandas.

# %%
for file in files:

    # connect to database
    connection = sqlite3.connect( file )

    # create an animalPool, which basically contains your animals
    animalPool = AnimalPool()

    # load infos about the animals
    animalPool.loadAnimals( connection )

    # load all detection (positions) of all animals for the first hour
    animalPool.loadDetection( start = 0, end = oneHour )

    eventTimeLine = EventTimeLine( connection, "Oral-genital Contact", idA = 1 , idB = 2, minFrame = 0, maxFrame = oneHour )

    print ( "Event list for label ", eventTimeLine.eventNameWithId )
    print ( "for animal 1:", animalPool.getAnimalDictionnary()[1].RFID )
    print ( "for animal 2:", animalPool.getAnimalDictionnary()[2].RFID )
    print ( "Number of events:", len( eventTimeLine.getEventList() ) )

    import pandas as pd
    
    #df = pd.DataFrame( columns=( "Start frame","End frame", "Duration (in frame)" )
    #print ( "start frame","end frame", "duration(in frame)")        
    
    data = []
    
    for event in eventTimeLine.eventList:
        data.append( [ event.startFrame, event.endFrame, event.duration() ] )
        #print( event.startFrame, event.endFrame, event.duration() )

import pandas as pd
import numpy as np

df = pd.DataFrame( data = np.array( data ), columns=[ "Start frame","End frame", "Duration (in frame)" ] )

df
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.35938239097595215 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.5000247955322266 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.4687199592590332 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.48206257820129395 seconds.
# Oral-genital Contact  Id( 1 , 2 , None , None ) Loaded ( 49  records loaded in  0.0707552433013916 S )
# Event list for label  Oral-genital Contact idA:1 idB:2 idC:None idD:None
# for animal 1: 000004395862
# for animal 2: 000004395854
# Number of events: 49
#     Start frame  End frame  Duration (in frame)
# 0           217        221                    5
# 1           552        559                    8
# 2           693        694                    2
# 3          3265       3267                    3
# 4          3710       3718                    9
# 5          4494       4494                    1
# 6          4496       4501                    6
# 7          4542       4542                    1
# 8          4545       4545                    1
# 9          4553       4553                    1
# 10         6279       6280                    2
# 11         8465       8478                   14
# 12         9527       9527                    1
# 13         9918       9919                    2
# 14        10511      10514                    4
# 15        10516      10519                    4
# 16        11524      11528                    5
# 17        11561      11582                   22
# 18        11821      11822                    2
# 19        11829      11833                    5
# 20        11841      11844                    4
# 21        12258      12258                    1
# 22        12260      12263                    4
# 23        12267      12267                    1
# 24        12270      12274                    5
# 25        12276      12276                    1
# 26        12278      12278                    1
# 27        12281      12284                    4
# 28        12295      12314                   20
# 29        12399      12399                    1
# 30        14190      14197                    8
# 31        14203      14205                    3
# 32        14359      14365                    7
# 33        14370      14370                    1
# 34        14708      14708                    1
# 35        14710      14712                    3
# 36        14714      14720                    7
# 37        14722      14726                    5
# 38        14764      14764                    1
# 39        14769      14771                    3
# 40        15799      15800                    2
# 41        16945      16945                    1
# 42        20022      20023                    2
# 43        20027      20029                    3
# 44        20072      20072                    1
# 45        20074      20074                    1
# 46        21553      21553                    1
# 47        23239      23248                   10
# 48        23259      23264                    6

# %% [markdown]
# ## Show the mask of the animal at t=300
#
# This code grabs the data from the *data* field of the detection table. It unzip the mask used as region of interest to display it in a figure, so that you can see the silhouette of the animals

# %%
for file in files:

    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    
    # show the mask of animals at frame 300
    animalPool.showMask( 300 )
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# TEST
# SELECT DATA FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER=300
# TEST
# SELECT DATA FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER=300
# TEST
# SELECT DATA FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER=300
# TEST
# SELECT DATA FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER=300

# %% [markdown]
# # Show (x,y,z) position of the first animal
# For the purpose of the example and for the limit the output size, we take the first file, and we process the first animal

# %%
file = files[0]
    
# connect to database
connection = sqlite3.connect( file )

# create an animalPool, which basically contains your animals
animalPool = AnimalPool()

animalPool.loadAnimals( connection )

# load all detection (positions) of all animals for the first hour
animalPool.loadDetection( start = 0, end = oneHour )

animal = animalPool.animalDictionnary[1]

print ("******")
print ( animal )

print ("Position coordinates:")

data = []

for detectionKey in animal.detectionDictionnary:
    detection = animal.detectionDictionnary[ detectionKey ]
    t = detectionKey
    x = detection.massX
    y = detection.massY
    z = detection.massZ
    data.append( [ t,x,y,z ] )

df = pd.DataFrame( data = np.array( data ), columns=[ "frame number", "x","y","z" ] )

df
# Out:
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None   23873  detections loaded in 0.42187023162841797 seconds.
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:2 Name:B RFID:000004395854 Genotype:None User1:None   23863  detections loaded in 0.4062647819519043 seconds.
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:3 Name:C RFID:000004396001 Genotype:None User1:None   23671  detections loaded in 0.45311856269836426 seconds.
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=108000
# Animal Id:4 Name:D RFID:000004395671 Genotype:None User1:None   23864  detections loaded in 0.45311594009399414 seconds.
# ******
# Animal Id:1 Name:A RFID:000004395862 Genotype:None User1:None
# Position coordinates:
#        frame number       x       y      z
# 0               2.0  274.31  333.42  57.16
# 1               3.0  276.53  333.90  56.16
# 2               4.0  279.30  333.53  55.84
# 3               5.0  282.30  333.28  56.40
# 4               6.0  285.72  333.53  56.36
# 5               7.0  289.43  335.09  58.72
# 6               8.0  293.79  336.69  56.20
# 7               9.0  298.62  337.43  54.88
# 8              10.0  303.53  338.12  54.96
# 9              11.0  309.12  339.53  56.84
# 10             12.0  313.81  340.72  58.48
# 11             13.0  318.41  341.46  56.08
# 12             14.0  323.17  342.84  55.24
# 13             15.0  328.09  344.38  55.00
# 14             16.0  332.05  344.36  51.72
# 15             17.0  336.40  343.45  51.40
# 16             18.0  341.87  343.79  57.08
# 17             19.0  342.90  344.88  59.60
# 18             20.0  350.30  343.10  59.00
# 19             21.0  354.49  342.03  57.48
# 20             22.0  358.04  341.35  58.80
# 21             23.0  362.03  341.16  56.92
# 22             24.0  365.70  341.29  57.36
# 23             25.0  369.71  341.70  57.36
# 24             26.0  372.73  342.02  63.96
# 25             27.0  374.62  341.44  63.20
# 26             28.0  375.69  341.79  65.28
# 27             29.0  376.35  341.95  61.92
# 28             30.0  376.83  342.30  63.36
# 29             31.0  377.26  342.84  62.16
# ...             ...     ...     ...    ...
# 23843       23861.0  371.20  265.29  63.84
# 23844       23862.0  371.34  264.45  66.24
# 23845       23863.0  371.85  263.50  62.80
# 23846       23864.0  372.50  262.28  63.68
# 23847       23865.0  373.29  261.07  61.20
# 23848       23866.0  374.28  260.36  61.56
# 23849       23867.0  374.79  259.62  59.52
# 23850       23868.0  375.43  258.97  56.84
# 23851       23869.0  376.22  258.48  54.88
# 23852       23870.0  376.83  258.37  54.88
# 23853       23871.0  377.28  257.61  52.92
# 23854       23872.0  377.59  256.60  54.24
# 23855       23873.0  378.07  253.79  50.04
# 23856       23874.0  378.32  250.10  48.08
# 23857       23875.0  379.24  246.99  48.20
# 23858       23876.0  379.78  243.95  50.88
# 23859       23877.0  380.21  239.59  53.60
# 23860       23878.0  379.24  237.62  52.68
# 23861       23879.0  378.02  235.08  54.52
# 23862       23880.0  377.10  231.63  52.20
# 23863       23881.0  376.82  226.89  51.08
# 23864       23882.0  376.91  221.97  48.60
# 23865       23883.0  377.95  217.28  49.64
# 23866       23884.0  378.88  213.21  54.52
# 23867       23885.0  379.71  208.91  57.92
# 23868       23886.0  379.23  204.64  58.52
# 23869       23887.0  379.01  199.32  57.88
# 23870       23888.0  379.59  192.90  54.28
# 23871       23889.0  378.98  187.59  51.08
# 23872       23890.0  379.36  182.93  51.96
#
# [23873 rows x 4 columns]
