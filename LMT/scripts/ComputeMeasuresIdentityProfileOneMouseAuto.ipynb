# %% [markdown]
# # Animal profile
#
# This file creates the profile output for a group of animals.
#
# | ![](../images/profile.jpg) |
# |:--:|
# |Example of profile. 1 point per animal. Each color represents one cage|
#
# This code computes the total time spent in each behaviour as well as the total number of occurrences of this behaviour for each individual. You can choose to compute this profile either over all the experiment or for each night separately. It provides a plot for the total duration of all the different events and a plot for the total number of occurrences of each behaviour as pdf files. It also provides a txt file with all individual values for each variable, as well as statistics (mixed model for each trait, uncorrected: trait as a function of genotype, with a group effect).

# %%
'''
Created on 13 sept. 2017

@author: Fabrice de Chaumont and Elodie Ey
'''

import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import numpy as np
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import colorsys
from collections import Counter
import seaborn as sns

from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput
from lmtanalysis.EventTimeLineCache import EventTimeLineCached
from lmtanalysis.FileUtil import getFilesToProcess
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas


def computeProfile(file, minT, maxT, night):
    
    connection = sqlite3.connect( file )
    
    pool = AnimalPool( )
    pool.loadAnimals( connection )
    
    animalData = {}
    
    for animal in pool.animalDictionnary.keys():
        
        print( "computing individual animal: {}".format( animal ))
        rfid = pool.animalDictionnary[animal].RFID
        print( "RFID: {}".format( rfid ) )
        animalData[rfid]= {}        
        #store the animal
        animalData[rfid]["animal"] = pool.animalDictionnary[animal]
        animalData[rfid]["file"] = file
                
        genoA = None
        try:
            genoA=pool.animalDictionnary[animal].genotype
        except:
            pass
                    
        for behavEvent in behaviouralEventOneMouse[:-2]:
            
            print( "computing individual event: {}".format(behavEvent))    
            
            behavEventTimeLine = EventTimeLineCached( connection, file, behavEvent, animal, minFrame=minT, maxFrame=maxT )
            
            totalEventDuration = behavEventTimeLine.getTotalLength()
            nbEvent = behavEventTimeLine.getNumberOfEvent(minFrame = minT, maxFrame = maxT )
            print( "total event duration: " , totalEventDuration )                
            animalData[rfid][behavEventTimeLine.eventName+" TotalLen"] = totalEventDuration
            animalData[rfid][behavEventTimeLine.eventName+" Nb"] = nbEvent
            
            print(behavEventTimeLine.eventName, genoA, behavEventTimeLine.idA, totalEventDuration, nbEvent)

    
    header = ["file","strain","sex","group","day","exp","RFID","genotype", "user1", "minTime","maxTime"]
    for name in header:
        text_file.write( "{}\t".format ( name ) ) 
    for kAnimal in animalData:    
        #identify the experiment where the animal comes from:
        animalData[kAnimal]["experiment"] = file
        #compute the total distance traveled
        COMPUTE_TOTAL_DISTANCE = True
        if ( COMPUTE_TOTAL_DISTANCE == True ):
            animalData[kAnimal]["animal"].loadDetection( start=minT, end=maxT, lightLoad = True )
            animalData[kAnimal]["totalDistance"] = animalData[kAnimal]["animal"].getDistance( tmin=minT,tmax=maxT)/100
        else:
            animalData[kAnimal]["totalDistance"] = "totalDistance"
        
    #write event keys
    firstAnimalKey = next(iter(animalData))
    firstAnimal = animalData[firstAnimalKey]
    for k in firstAnimal.keys():
        text_file.write( "{}\t".format( k.replace(" ", "") ) )
    text_file.write("\n")
    
    for kAnimal in animalData:
        text_file.write( "{}\t".format( file ) )
        text_file.write( "{}\t".format( "strain" ) )
        text_file.write( "{}\t".format( "sex" ) )
        text_file.write( "{}\t".format( "group" ) )
        text_file.write( "{}\t".format( night ) )
        text_file.write( "{}\t".format( "exp" ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].RFID ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].genotype ) )
        text_file.write( "{}\t".format( animalData[kAnimal]["animal"].user1 ) )
        text_file.write( "{}\t".format( minT ) )
        text_file.write( "{}\t".format( maxT ) )

        for kEvent in firstAnimal.keys():
            text_file.write( "{}\t".format( animalData[kAnimal][kEvent] ) )
        text_file.write( "\n" )
        
    return animalData


def getProfileValues( profileData, night=0, event=None):
    dataDic = {}
    dataDic["genotype"] = []
    dataDic["value"] = []
    dataDic["exp"] = []
    
    for file in profileData.keys():
        for animal in profileData[file][night]:
            dataDic["value"].append(profileData[file][night][animal][event])
            dataDic["exp"].append(profileData[file][night][animal]["experiment"])
            dataDic["genotype"].append(profileData[file][night][animal]["animal"].genotype)
    
    return dataDic


def plotProfileDataDuration(profileData, night, valueCat):
    fig, axes = plt.subplots(nrows=5, ncols=6, figsize=(14, 12))
    
    row=0
    col=0
    fig.suptitle(t="{} of events (night {})".format(valueCat, night), y=1.2, fontweight= 'bold')
    
    #plot the data for each behavioural event
    for behavEvent in behaviouralEventOneMouse[:-2]:
        event = behavEvent+valueCat
        print("event: ", event)
        
        profileValueDictionary = getProfileValues(profileData=profileData, night=night, event=event)
        y = profileValueDictionary["value"]
        x = profileValueDictionary["genotype"]
        genotypeType = Counter(x)
        group = profileValueDictionary["exp"]
        
        print("y: ", y)
        print("x: ", x)
        print("group: ", group)
        experimentType = Counter(group)
        print("Nb of experiments: ", len(experimentType))
        
        axes[row,col].set_xlim(-0.5, 1.5)
        axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
        sns.stripplot(x, y, jitter=True, hue=group, s=5, ax=axes[row,col] )
        axes[row,col].set_title(behavEvent)
        axes[row,col].set_ylabel("{} (frames)".format(valueCat))
        axes[row,col].legend().set_visible(False)
        axes[row,col].spines['right'].set_visible(False)
        axes[row,col].spines['top'].set_visible(False)
        
        if col<5:
            col+=1
            row=row
        else:
            col=0
            row+=1
    
    #plot the data for the total distance traveled   
    profileValueDictionary = getProfileValues(profileData=profileData, night=night, event="totalDistance")
    y = profileValueDictionary["value"]
    x = profileValueDictionary["genotype"]
    genotypeType = Counter(x)
    group = profileValueDictionary["exp"]
    
    print("y: ", y)
    print("x: ", x)
    print("group: ", group)
    experimentType = Counter(group)
    print("Nb of experiments: ", len(experimentType))
    
    axes[row,col].set_xlim(-0.5, 1.5)
    axes[row,col].set_ylim(min(y)-0.2*max(y), max(y)+0.2*max(y))
    sns.stripplot(x, y, jitter=True, hue=group, s=5, ax=axes[row,col] )
    axes[row,col].set_title("Activity")
    axes[row,col].set_ylabel("total distance (m)")
    axes[row,col].legend().set_visible(False)
    axes[row,col].spines['right'].set_visible(False)
    axes[row,col].spines['top'].set_visible(False)
    
    if col<7:
        col+=1
        row=row
    else:
        col=0
        row+=1
    
    fig.tight_layout()
    figFileName = "FigProfile{}_Events_night_{}.pdf".format( valueCat, night )
    print("Saving " , figFileName )
    fig.savefig( figFileName ,dpi=100)
    plt.close( fig )
    

def testProfileData(profileData=None, night=0, eventListNames=None, valueCat="", text_file=None):
    for behavEvent in eventListNames:
        event = behavEvent+valueCat
        print("event: ", event)
        text_file.write("Test for the event: {} night {}".format( event, night ) )
        
        profileValueDictionary = getProfileValues(profileData=profileData, night=night, event=event)
        
        dfData = pandas.DataFrame({'group': profileValueDictionary["exp"],
                                   'genotype': profileValueDictionary["genotype"],
                                   'value': profileValueDictionary["value"]})
        
        #pandas.DataFrame(dfData).info()
        #Mixed model: variable to explain: value; fixed factor = genotype; random effect: group
        #create model:
        model = smf.mixedlm("value ~ genotype", dfData, groups = dfData["group"])
        #run model: 
        result = model.fit()
        #print summary
        print(result.summary())
        text_file.write(result.summary().as_text())


if __name__ == '__main__':
    
    print("Code launched.")
    
    #List of events to be computed within the behavioural profile, and header for the computation of the total distance travelled.
    behaviouralEventOneMouse = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", "Side by side Contact, opposite way", "Social approach", "Get away", "Approach contact", "Approach rear", "Break contact", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group 3 break", "Group 3 make", "Group 4 break", "Group 4 make", "Huddling", "Move isolated", "Move in contact", "Nest3", "Nest4", "Rearing", "Rear isolated", "Rear in contact", "Stop isolated", "WallJump", "Water Zone", "totalDistance", "experiment"]
    #behaviouralEventOneMouse = ["Contact", "totalDistance", "experiment"]

    files = getFilesToProcess()
    tmin, tmax, text_file = getMinTMaxTAndFileNameInput()

    profileData = {}
    nightComputation = input("Compute profile only during night events (Y or N)? ")
    
    for file in files:
        
        print(file)
        connection = sqlite3.connect( file )
    
        profileData[file] = {}
    
        pool = AnimalPool( )
        pool.loadAnimals( connection )

        if nightComputation == "N":
            minT = tmin
            maxT = tmax
            n = 0
            #Compute profile data and save them in a text file
            profileData[file][n] = computeProfile(file = file, minT=minT, maxT=maxT, night=n)
            text_file.write( "\n" )
            print("Profile data saved.")
            
        else:
            nightEventTimeLine = EventTimeLineCached( connection, file, "night", minFrame=tmin, maxFrame=tmax )
            n = 1
            
            for eventNight in nightEventTimeLine.getEventList():
                minT = eventNight.startFrame
                maxT = eventNight.endFrame
                print("Night: ", n)
                #Compute profile data and save them in a text file
                profileData[file][n] = computeProfile(file=file, minT=minT, maxT=maxT, night=n)
                text_file.write( "\n" )
                n+=1
                print("Profile data saved.")
            
            
    text_file.write( "\n" )
    
    if nightComputation == "N":
        n = 0

        #Plot profile data and save them in a pdf file
        plotProfileDataDuration(profileData=profileData, night=n, valueCat=" TotalLen")
        plotProfileDataDuration(profileData=profileData, night=n, valueCat=" Nb")
        text_file.write( "Statistical analysis: mixed linear models" )
        text_file.write( "{}\n" )
        #Test profile data and save results in a text file
        '''
        testProfileData(profileData=profileData, night=n, eventListNames=behaviouralEventOneMouse[:-2], valueCat=" TotalLen", text_file=text_file)
        testProfileData(profileData=profileData, night=n, eventListNames=behaviouralEventOneMouse[:-2], valueCat=" Nb", text_file=text_file)
        print("test for total distance")
        testProfileData(profileData=profileData, night=n, eventListNames=["totalDistance"], valueCat="", text_file=text_file)
        '''
            
    else:
        nightEventTimeLine = EventTimeLineCached( connection, file, "night", minFrame=tmin, maxFrame=tmax )
        n = 1
        
        for eventNight in nightEventTimeLine.getEventList():

            print("Night: ", n)
               
            #Plot profile data and save them in a pdf file
            plotProfileDataDuration(profileData=profileData, night=n, valueCat=" TotalLen")
            plotProfileDataDuration(profileData=profileData, night=n, valueCat=" Nb")
            text_file.write( "Statistical analysis: mixed linear models" )
            text_file.write( "{}\n" )
            #Test profile data and save results in a text file
            '''
            testProfileData(profileData=profileData, night=n, eventListNames=behaviouralEventOneMouse[:-2], valueCat=" TotalLen", text_file=text_file)
            testProfileData(profileData=profileData, night=n, eventListNames=behaviouralEventOneMouse[:-2], valueCat=" Nb", text_file=text_file)
            print("test for total distance")
            testProfileData(profileData=profileData, night=n, eventListNames=["totalDistance"], valueCat="", text_file=text_file)
            '''
            n+=1
            
    
    print ("Plots saved as pdf and analyses saved in text file.")
    
    text_file.close()
# Out:
# Code launched.
# Enter time information in frame. You can also set in days, hour, minutes
# valid entries: 100, 1d, 1.5d, 23.5h, 1d 2h 3m 4s 5f
# Starting t : 0
# Entry (in frame) : 0
# Ending t : 1d
# Entry (in frame) : 2592000
# Enter file name to save data (.txt will be added) : t
# Compute profile only during night events (Y or N)? N
# D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME', 'AGE', 'SEX', 'STRAIN']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE,AGE,SEX,STRAIN FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849294 Genotype:KO User1:None
# Animal Id:2 Name:B RFID:000004849144 Genotype:KO User1:None
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME', 'AGE', 'SEX', 'STRAIN']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE,AGE,SEX,STRAIN FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004849294 Genotype:KO User1:None
# Animal Id:2 Name:B RFID:000004849144 Genotype:KO User1:None
# computing individual animal: 1
# RFID: 000004849294
# computing individual event: Contact
# Contact  Id( 1 , None , None , None ) Loaded from cache ( 6287  records. )
# total event duration:  435633
# Contact KO 1 435633 6287
# computing individual event: Oral-oral Contact
# Oral-oral Contact  Id( 1 , None , None , None ) Loaded from cache ( 13003  records. )
# total event duration:  93050
# Oral-oral Contact KO 1 93050 13003
# computing individual event: Oral-genital Contact
# Oral-genital Contact  Id( 1 , None , None , None ) Loaded from cache ( 11560  records. )
# total event duration:  56402
# Oral-genital Contact KO 1 56402 11560
# computing individual event: Side by side Contact
# Side by side Contact  Id( 1 , None , None , None ) Loaded from cache ( 8638  records. )
# total event duration:  102258
# Side by side Contact KO 1 102258 8638
# computing individual event: Side by side Contact, opposite way
# Side by side Contact, opposite way  Id( 1 , None , None , None ) Loaded from cache ( 8585  records. )
# total event duration:  101874
# Side by side Contact, opposite way KO 1 101874 8585
# computing individual event: Social approach
# Social approach  Id( 1 , None , None , None ) Loaded from cache ( 56287  records. )
# total event duration:  146692
# Social approach KO 1 146692 56287
# computing individual event: Get away
# Get away  Id( 1 , None , None , None ) Loaded from cache ( 36093  records. )
# total event duration:  121761
# Get away KO 1 121761 36093
# computing individual event: Approach contact
# Approach contact  Id( 1 , None , None , None ) Loaded from cache ( 47567  records. )
# total event duration:  123628
# Approach contact KO 1 123628 47567
# computing individual event: Approach rear
# Approach rear  Id( 1 , None , None , None ) Loaded from cache ( 9297  records. )
# total event duration:  26132
# Approach rear KO 1 26132 9297
# computing individual event: Break contact
# Break contact  Id( 1 , None , None , None ) Loaded from cache ( 1623  records. )
# total event duration:  22094
# Break contact KO 1 22094 1623
# computing individual event: FollowZone Isolated
# FollowZone Isolated  Id( 1 , None , None , None ) Loaded from cache ( 7858  records. )
# total event duration:  16749
# FollowZone Isolated KO 1 16749 7858
# computing individual event: Train2
# Train2  Id( 1 , None , None , None ) Loaded from cache ( 76  records. )
# total event duration:  638
# Train2 KO 1 638 76
# computing individual event: Group2
# Group2  Id( 1 , None , None , None ) Loaded from cache ( 6287  records. )
# total event duration:  435633
# Group2 KO 1 435633 6287
# computing individual event: Group3
# Group3  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group3 KO 1 0 0
# computing individual event: Group 3 break
# Group 3 break  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 3 break KO 1 0 0
# computing individual event: Group 3 make
# Group 3 make  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 3 make KO 1 0 0
# computing individual event: Group 4 break
# Group 4 break  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 4 break KO 1 0 0
# computing individual event: Group 4 make
# Group 4 make  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 4 make KO 1 0 0
# computing individual event: Huddling
# Huddling  Id( 1 , None , None , None ) Loaded from cache ( 79454  records. )
# total event duration:  368573
# Huddling KO 1 368573 79454
# computing individual event: Move isolated
# Move isolated  Id( 1 , None , None , None ) Loaded from cache ( 17865  records. )
# total event duration:  171570
# Move isolated KO 1 171570 17865
# computing individual event: Move in contact
# Move in contact  Id( 1 , None , None , None ) Loaded from cache ( 10202  records. )
# total event duration:  46619
# Move in contact KO 1 46619 10202
# computing individual event: Nest3
# Nest3  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Nest3 KO 1 0 0
# computing individual event: Nest4
# Nest4  Id( 1 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Nest4 KO 1 0 0
# computing individual event: Rearing
# Rearing  Id( 1 , None , None , None ) Loaded from cache ( 20740  records. )
# total event duration:  1671307
# Rearing KO 1 1671307 20740
# computing individual event: Rear isolated
# Rear isolated  Id( 1 , None , None , None ) Loaded from cache ( 9648  records. )
# total event duration:  43809
# Rear isolated KO 1 43809 9648
# computing individual event: Rear in contact
# Rear in contact  Id( 1 , None , None , None ) Loaded from cache ( 7551  records. )
# total event duration:  21184
# Rear in contact KO 1 21184 7551
# computing individual event: Stop isolated
# Stop isolated  Id( 1 , None , None , None ) Loaded from cache ( 20140  records. )
# total event duration:  1732238
# Stop isolated KO 1 1732238 20140
# computing individual event: WallJump
# WallJump  Id( 1 , None , None , None ) Loaded from cache ( 818  records. )
# total event duration:  1807
# WallJump KO 1 1807 818
# computing individual event: Water Zone
# Water Zone  Id( 1 , None , None , None ) Loaded from cache ( 574  records. )
# total event duration:  166335
# Water Zone KO 1 166335 574
# computing individual animal: 2
# RFID: 000004849144
# computing individual event: Contact
# Contact  Id( 2 , None , None , None ) Loaded from cache ( 6287  records. )
# total event duration:  435633
# Contact KO 2 435633 6287
# computing individual event: Oral-oral Contact
# Oral-oral Contact  Id( 2 , None , None , None ) Loaded from cache ( 13003  records. )
# total event duration:  93050
# Oral-oral Contact KO 2 93050 13003
# computing individual event: Oral-genital Contact
# Oral-genital Contact  Id( 2 , None , None , None ) Loaded from cache ( 11785  records. )
# total event duration:  55121
# Oral-genital Contact KO 2 55121 11785
# computing individual event: Side by side Contact
# Side by side Contact  Id( 2 , None , None , None ) Loaded from cache ( 8638  records. )
# total event duration:  102258
# Side by side Contact KO 2 102258 8638
# computing individual event: Side by side Contact, opposite way
# Side by side Contact, opposite way  Id( 2 , None , None , None ) Loaded from cache ( 8585  records. )
# total event duration:  101874
# Side by side Contact, opposite way KO 2 101874 8585
# computing individual event: Social approach
# Social approach  Id( 2 , None , None , None ) Loaded from cache ( 56652  records. )
# total event duration:  152542
# Social approach KO 2 152542 56652
# computing individual event: Get away
# Get away  Id( 2 , None , None , None ) Loaded from cache ( 42243  records. )
# total event duration:  167772
# Get away KO 2 167772 42243
# computing individual event: Approach contact
# Approach contact  Id( 2 , None , None , None ) Loaded from cache ( 47841  records. )
# total event duration:  129583
# Approach contact KO 2 129583 47841
# computing individual event: Approach rear
# Approach rear  Id( 2 , None , None , None ) Loaded from cache ( 9765  records. )
# total event duration:  27969
# Approach rear KO 2 27969 9765
# computing individual event: Break contact
# Break contact  Id( 2 , None , None , None ) Loaded from cache ( 2006  records. )
# total event duration:  30499
# Break contact KO 2 30499 2006
# computing individual event: FollowZone Isolated
# FollowZone Isolated  Id( 2 , None , None , None ) Loaded from cache ( 8272  records. )
# total event duration:  17545
# FollowZone Isolated KO 2 17545 8272
# computing individual event: Train2
# Train2  Id( 2 , None , None , None ) Loaded from cache ( 50  records. )
# total event duration:  423
# Train2 KO 2 423 50
# computing individual event: Group2
# Group2  Id( 2 , None , None , None ) Loaded from cache ( 6287  records. )
# total event duration:  435633
# Group2 KO 2 435633 6287
# computing individual event: Group3
# Group3  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group3 KO 2 0 0
# computing individual event: Group 3 break
# Group 3 break  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 3 break KO 2 0 0
# computing individual event: Group 3 make
# Group 3 make  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 3 make KO 2 0 0
# computing individual event: Group 4 break
# Group 4 break  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 4 break KO 2 0 0
# computing individual event: Group 4 make
# Group 4 make  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Group 4 make KO 2 0 0
# computing individual event: Huddling
# Huddling  Id( 2 , None , None , None ) Loaded from cache ( 39791  records. )
# total event duration:  145859
# Huddling KO 2 145859 39791
# computing individual event: Move isolated
# Move isolated  Id( 2 , None , None , None ) Loaded from cache ( 23672  records. )
# total event duration:  253825
# Move isolated KO 2 253825 23672
# computing individual event: Move in contact
# Move in contact  Id( 2 , None , None , None ) Loaded from cache ( 10976  records. )
# total event duration:  51148
# Move in contact KO 2 51148 10976
# computing individual event: Nest3
# Nest3  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Nest3 KO 2 0 0
# computing individual event: Nest4
# Nest4  Id( 2 , None , None , None ) Loaded from cache ( 0  records. )
# total event duration:  0
# Nest4 KO 2 0 0
# computing individual event: Rearing
# Rearing  Id( 2 , None , None , None ) Loaded from cache ( 24369  records. )
# total event duration:  1608885
# Rearing KO 2 1608885 24369
# computing individual event: Rear isolated
# Rear isolated  Id( 2 , None , None , None ) Loaded from cache ( 12794  records. )
# total event duration:  50910
# Rear isolated KO 2 50910 12794
# computing individual event: Rear in contact
# Rear in contact  Id( 2 , None , None , None ) Loaded from cache ( 7451  records. )
# total event duration:  22272
# Rear in contact KO 2 22272 7451
# computing individual event: Stop isolated
# Stop isolated  Id( 2 , None , None , None ) Loaded from cache ( 23398  records. )
# total event duration:  1249463
# Stop isolated KO 2 1249463 23398
# computing individual event: WallJump
# WallJump  Id( 2 , None , None , None ) Loaded from cache ( 881  records. )
# total event duration:  1923
# WallJump KO 2 1923 881
# computing individual event: Water Zone
# Water Zone  Id( 2 , None , None , None ) Loaded from cache ( 758  records. )
# total event duration:  131505
# Water Zone KO 2 131505 758
# Animal Id:1 Name:A RFID:000004849294 Genotype:KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=2592000
# Animal Id:1 Name:A RFID:000004849294 Genotype:KO User1:None   2339441  detections loaded in 7.765626668930054 seconds.
# Compute total distance min:0 max:2592000
# Animal Id:2 Name:B RFID:000004849144 Genotype:KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=2592000
# Animal Id:2 Name:B RFID:000004849144 Genotype:KO User1:None   1938920  detections loaded in 5.881359815597534 seconds.
# Compute total distance min:0 max:2592000
# Profile data saved.
# event:  Contact TotalLen
# y:  [435633, 435633]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Oral-oral Contact TotalLen
# y:  [93050, 93050]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Oral-genital Contact TotalLen
# y:  [56402, 55121]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact TotalLen
# y:  [102258, 102258]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact, opposite way TotalLen
# y:  [101874, 101874]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Social approach TotalLen
# y:  [146692, 152542]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Get away TotalLen
# C:\Users\Fab\Anaconda3bis\lib\site-packages\matplotlib\axes\_base.py:3285: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))
# y:  [121761, 167772]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Approach contact TotalLen
# y:  [123628, 129583]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Approach rear TotalLen
# y:  [26132, 27969]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Break contact TotalLen
# y:  [22094, 30499]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  FollowZone Isolated TotalLen
# y:  [16749, 17545]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Train2 TotalLen
# y:  [638, 423]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group2 TotalLen
# y:  [435633, 435633]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group3 TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 3 break TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 3 make TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 4 break TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 4 make TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Huddling TotalLen
# y:  [368573, 145859]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Move isolated TotalLen
# y:  [171570, 253825]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Move in contact TotalLen
# y:  [46619, 51148]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Nest3 TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Nest4 TotalLen
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rearing TotalLen
# y:  [1671307, 1608885]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rear isolated TotalLen
# y:  [43809, 50910]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rear in contact TotalLen
# y:  [21184, 22272]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Stop isolated TotalLen
# y:  [1732238, 1249463]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  WallJump TotalLen
# y:  [1807, 1923]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Water Zone TotalLen
# y:  [166335, 131505]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# y:  [2687.89321757086, 3164.5991478334454]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Contact Nb
# y:  [6287, 6287]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Oral-oral Contact Nb
# y:  [13003, 13003]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Oral-genital Contact Nb
# y:  [11560, 11785]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact Nb
# y:  [8638, 8638]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Side by side Contact, opposite way Nb
# y:  [8585, 8585]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Social approach Nb
# y:  [56287, 56652]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Get away Nb
# y:  [36093, 42243]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Approach contact Nb
# y:  [47567, 47841]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Approach rear Nb
# y:  [9297, 9765]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Break contact Nb
# y:  [1623, 2006]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  FollowZone Isolated Nb
# y:  [7858, 8272]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Train2 Nb
# y:  [76, 50]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group2 Nb
# y:  [6287, 6287]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group3 Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 3 break Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 3 make Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 4 break Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Group 4 make Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Huddling Nb
# y:  [79454, 39791]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Move isolated Nb
# y:  [17865, 23672]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Move in contact Nb
# y:  [10202, 10976]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Nest3 Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Nest4 Nb
# y:  [0, 0]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rearing Nb
# y:  [20740, 24369]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rear isolated Nb
# y:  [9648, 12794]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Rear in contact Nb
# y:  [7551, 7451]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Stop isolated Nb
# y:  [20140, 23398]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  WallJump Nb
# y:  [818, 881]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# event:  Water Zone Nb
# y:  [574, 758]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# y:  [2687.89321757086, 3164.5991478334454]
# x:  ['KO', 'KO']
# group:  ['D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite', 'D:/usv_shank3/20191014_usv_lmt_pair_shank3_4849144_4849294/20191014_usv_lmt_pair_shank3_4849144_4849294.sqlite']
# Nb of experiments:  1
# Plots saved as pdf and analyses saved in text file.
