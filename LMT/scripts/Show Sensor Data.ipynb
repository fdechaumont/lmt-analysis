# %% [markdown]
# # Show sensor data
#
# - This script plots the sensor data and save it in pdf figures.
# - Sensor supported : temperature, sound level, humidity, visible light, visible + infrared light.
#
# | ![](../images/sensor.jpg) |
# |:--:|
# |Example of temperature graph. (bounded to 18-28°C)|

# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from tkinter.filedialog import askopenfilename
import sys
from lmtanalysis.FileUtil import getFilesToProcess

class FileProcessException(Exception):
    pass

def process( file ):
    
    connection = sqlite3.connect( file )     

    print( "--------------")
    print( "Current file: ", file )
    
    connection = sqlite3.connect( file )
    # build sensor data
    animalPool = AnimalPool( )
    animalPool.loadAnimals( connection )
    animalPool.buildSensorData( file, show = True  )
    
print("Code launched.")

files = getFilesToProcess()

if ( files != None ):

    for file in files:
        try:
            print ( "Processing file" , file )
            process( file )
        except FileProcessException:
            print ( "STOP PROCESSING FILE " + file , file=sys.stderr  )

print( "*** ALL JOBS DONE ***")
# Out:
# Code launched.
# Processing file D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004415712 Genotype:B6J User1:None
# Animal Id:3 Name:C RFID:000004420257 Genotype:B6J User1:None
# Animal Id:1 Name:A RFID:000004719996 Genotype:B6N User1:None
# Animal Id:4 Name:D RFID:000004736209 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  24.7690007686615 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.772987365722656 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.660982608795166 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.7069993019104 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.9046008586883545 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_04_Experiment 9390.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004419458 Genotype:B6J User1:None
# Animal Id:2 Name:B RFID:000004417894 Genotype:B6J User1:None
# Animal Id:3 Name:C RFID:000004736536 Genotype:B6N User1:None
# Animal Id:4 Name:D RFID:000004720130 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  27.423476934432983 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.239002466201782 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.339975595474243 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.154003381729126 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.597977638244629 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_05_Experiment 3984.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004417522 Genotype:B6J User1:None
# Animal Id:4 Name:D RFID:000004419462 Genotype:B6J User1:None
# Animal Id:1 Name:A RFID:000004720479 Genotype:B6N User1:None
# Animal Id:3 Name:C RFID:000004736221 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  58.842976093292236 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.48160195350647 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.678997755050659 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.52899694442749 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.65800404548645 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_06_Experiment 8458.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004736850 Genotype:B6J User1:None
# Animal Id:3 Name:C RFID:000004418571 Genotype:B6J User1:None
# Animal Id:1 Name:A RFID:000004719599 Genotype:B6N User1:None
# Animal Id:4 Name:D RFID:RFID_D Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  21.15653944015503 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.111985683441162 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.029017925262451 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.075016736984253 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.117983102798462 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190809_interlab_study_group_07_Experiment 259.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004418228 Genotype:B6J User1:None
# Animal Id:4 Name:D RFID:000004420397 Genotype:B6J User1:None
# Animal Id:2 Name:B RFID:000004724465 Genotype:B6N User1:None
# Animal Id:3 Name:C RFID:000004721645 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  29.455981492996216 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.523982524871826 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.490980625152588 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.432981729507446 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.527000904083252 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_08_Experiment 1723.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000004736605 Genotype:B6J User1:None
# Animal Id:3 Name:C RFID:000004417345 Genotype:B6J User1:None
# Animal Id:2 Name:B RFID:000004724215 Genotype:B6N User1:None
# Animal Id:4 Name:D RFID:000004724114 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  26.58851408958435 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.009989023208618 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.988110303878784 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  7.052011966705322 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.8970043659210205 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_09_Experiment 8775.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# Processing file D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite
# --------------
# Current file:  D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000004418230 Genotype:B6J User1:None
# Animal Id:4 Name:D RFID:000004722561 Genotype:B6J User1:None
# Animal Id:1 Name:A RFID:000004724078 Genotype:B6N User1:None
# Animal Id:3 Name:C RFID:000004720488 Genotype:B6N User1:None
# Build sensor data
# plotting sensor data.  TEMPERATURE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  63.03493666648865 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite_log_temperature.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  SOUND
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.598004579544067 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite_log_sound level.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  HUMIDITY
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.606995582580566 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite_log_humidity.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLE
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.721980571746826 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite_log_light visible.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# plotting sensor data.  LIGHTVISIBLEANDIR
# night  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3  records loaded in  6.927985668182373 S )
# Saving figure : D:/2019_08_interlab_study_processed_data/20190813_interlab_study_group_10_Experiment 5609.sqlite_log_light visible and infra.pdf
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# The entered framenumber is out of range
# *** ALL JOBS DONE ***
